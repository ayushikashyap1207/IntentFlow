# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushikashyap1207/IntentFlow/blob/main/intentflow_phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone your repo
# !git clone https://github.com/ayushikashyap1207/IntentFlow.git
# %cd IntentFlow

# Install all dependencies
# !pip install tensorflow mediapipe opencv-python chromadb \
  sentence-transformers langchain langchain-community \
  anthropic fastapi uvicorn pymongo streamlit \
  shap python-dotenv tqdm scikit-learn pandas -q

# Verify everything
import mediapipe as mp
import tensorflow as tf
import chromadb
import cv2
import anthropic
import fastapi
import streamlit

print("=" * 40)
print("IntentFlow - Colab Verification")
print("=" * 40)
print(f"  [OK] MediaPipe:    {mp.__version__}")
print(f"  [OK] TensorFlow:   {tf.__version__}")
print(f"  [OK] OpenCV:       {cv2.__version__}")
print(f"  [OK] ChromaDB:     {chromadb.__version__}")
print(f"  [OK] Anthropic:    {anthropic.__version__}")
print(f"  [OK] FastAPI:      {fastapi.__version__}")
print("=" * 40)
print("All OK — Ready for Phase 2!")
# Out:
# Cloning into 'IntentFlow'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'IntentFlow'
# /content
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 96.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 65.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 89.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.1/763.1 kB 43.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 73.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 104.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 23.8 MB/s eta 0:00:00
# ...
